# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
year = [1950,1970,1990,2010]

# %%
pop = [2.519,3.692,5.263,6.972]

# %%
plt.scatter(year,pop)

# %%
plt.show()

# %%
print(year[-1])
# Out:
# 2010

# %%
print(pop[-1])
# Out:
# 6.972

# %%
plt.xscale('log')

# %%
plt.show()

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, normed=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, hold=None, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*. The return value is a
#     tuple (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*,
#     [*patches0*, *patches1*,...]) if the input contains multiple
#     data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported at present.
#
#     Parameters
#     ----------
#     x : (n,) array or sequence of (n,) arrays
# ...

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,3.2,3.5,3.9,4.2,6]

# %%
plt.hist(values,bins = 3)
# Out:
# (array([ 4.,  5.,  2.]),
#  array([ 0.,  2.,  4.,  6.]),
#  <a list of 3 Patch objects>)

# %%
plt.show()

# %%
import unicodecsv

# %%
year = [1950,1970,1990,2010]
popu = [2.519,3.692,5.263,6.972]
plt.plot(year,popu)

# %%
plt.xlabel('Year')

# %%
plt.ylabel('population')

# %%
plt.title("wold population projections")

# %%
plt.yticks([0,2,4,6,8,10])
# Out:
# ([<matplotlib.axis.YTick at 0x11951e2b0>,
# ...
#  <a list of 6 Text yticklabel objects>)

# %%
xlab = 'GDP per Capita [in USD]'

# %%
ylab = 'Life Expectancy [in years]'

# %%
plt.xlabel(xlab)

# %%
plt.ylabel(ylab)

# %%
pop  =[1000000,2000000,3000000,4000000,5000000]

# %%
np_pop = np.array(pop)

# %%
np_pop = np_pop * 2

# %%
col = {
    '1950':'Blue',
    '1960':'Red'
}

# %%
plt.scatter(year,popu,s=np_pop)

# %%
plt.xscale('log')

# %%
plt.xticks([1000,10000,100000],['1k','10k','100k'])
# Out:
# ([<matplotlib.axis.XTick at 0x1194f52e8>,
# ...
#  <a list of 3 Text xticklabel objects>)

# %%
plt.text(1550,71,'India')

# %%
plt.text(3700,80,'China')

# %%
plt.grid(True)

# %%
plt.show()

# %%
pop = [30.55,2.77,39.21]

# %%
countries = ["afhanistan","albania","algeria"]

# %%
ind_alb = countries.index("albania")

# %%
ind_alb
# Out:
# 1

# %%
pop[ind_alb]
# Out:
# 2.77

# %%
world = {"afhanistan":30.55,"albania":2.77,"algeria":39.21}

# %%
world["albania"]
# Out:
# 2.77

# %%
europe = {"spain":"madrid","france":"paris","germany":"berlin","norway":"oslo"}

# %%
europe["france"]
# Out:
# 'paris'

# %%
europe.keys()
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])

# %%
world["sealand"] = 0.000027

# %%
world
# Out:
# {'afhanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 2.7e-05}

# %%
del(world["sealand"])

# %%
world
# Out:
# {'afhanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %%
europe['iceland'] = 'hello'

# %%
europe['italy'] = 'rome'

# %%
europe['poland'] = 'warsaw'

# %%
europe
# Out:
# {'france': 'paris',
#  'germany': 'berlin',
#  'iceland': 'hello',
#  'italy': 'rome',
#  'norway': 'oslo',
#  'poland': 'warsaw',
#  'spain': 'madrid'}

# %%
europe['germany'] = 'bonn'

# %%
del(europe['iceland'])

# %%
europe
# Out:
# {'france': 'paris',
#  'germany': 'bonn',
#  'italy': 'rome',
#  'norway': 'oslo',
#  'poland': 'warsaw',
#  'spain': 'madrid'}

# %%
europe = {'spain':{'capital':'madrid','population':46.77},
         'france':{'capital':'paris','population':66.03},
          'germany':{'capital':'berlin','population':80.62},
          'norway':{'capital':'oslo','population':5.084}
                    }

# %%
europe["france"]['population']
# Out:
# 66.03

# %%
data = {"capital":"rome","population":59.83}

# %%
europe['italy'] = data

# %%
europe
# Out:
# {'france': {'capital': 'paris', 'population': 66.03},
#  'germany': {'capital': 'berlin', 'population': 80.62},
#  'italy': {'capital': 'rome', 'population': 59.83},
#  'norway': {'capital': 'oslo', 'population': 5.084},
#  'spain': {'capital': 'madrid', 'population': 46.77}}

# %%
europe['italy']['capital']
# Out:
# 'rome'

# %%
import pandas as pd

# %%
europe_pd = pd.DataFrame(europe)

# %%
europe_pd
# Out:
#            france germany  italy norway   spain
# capital     paris  berlin   rome   oslo  madrid
# population  66.03   80.62  59.83  5.084   46.77

# %%
names = ['united states','Australia','Japan','India',"Russia",'Morocco','Egypt']

# %%
dr = [True,False,False,False,True,True,True]

# %%
cpc = [809,731,588,18,200,70,45]

# %%
my_dict = {'country':names,'drives_right':dr,'cars_per_cpc':cpc}

# %%
cars = pd.DataFrame(my_dict)

# %%
cars
# Out:
#    cars_per_cpc        country drives_right
# 0           809  united states         True
# 1           731      Australia        False
# 2           588          Japan        False
# 3            18          India        False
# 4           200         Russia         True
# 5            70        Morocco         True
# 6            45          Egypt         True

# %%
row_labels = ['US','AUS','JAP','IN','RU','MOR','EG']

# %%
cars.index = row_labels

# %%
cars
# Out:
#      cars_per_cpc        country drives_right
# US            809  united states         True
# AUS           731      Australia        False
# JAP           588          Japan        False
# IN             18          India        False
# RU            200         Russia         True
# MOR            70        Morocco         True
# EG             45          Egypt         True

# %%
cars["country"]
# Out:
# US     united states
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object

# %%
cars[["country","drives_right"]]
# Out:
#            country drives_right
# US   united states         True
# AUS      Australia        False
# JAP          Japan        False
# IN           India        False
# RU          Russia         True
# MOR        Morocco         True
# EG           Egypt         True

# %%
cars.loc[["US"]]
# Out:
#     cars_per_cpc        country drives_right
# US           809  united states         True

# %%
cars.loc[["AUS","JAP"]]
# Out:
#      cars_per_cpc    country drives_right
# AUS           731  Australia        False
# JAP           588      Japan        False

# %%
cars.iloc[[1]]
# Out:
#      cars_per_cpc    country drives_right
# AUS           731  Australia        False

# %%
cars.iloc[:,[0,1]]
# Out:
#      cars_per_cpc        country
# US            809  united states
# AUS           731      Australia
# JAP           588          Japan
# IN             18          India
# RU            200         Russia
# MOR            70        Morocco
# EG             45          Egypt

# %%
cars[:3]
# Out:
#      cars_per_cpc        country drives_right
# US            809  united states         True
# AUS           731      Australia        False
# JAP           588          Japan        False

# %%
cars[3:6]
# Out:
#      cars_per_cpc  country drives_right
# IN             18    India        False
# RU            200   Russia         True
# MOR            70  Morocco         True

# %%
cars.iloc[2]
# Out:
# cars_per_cpc      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object

# %%
cars.iloc[[2]]
# Out:
#      cars_per_cpc country drives_right
# JAP           588   Japan        False

# %%
cars.loc[["EG"]]
# Out:
#     cars_per_cpc country drives_right
# EG            45   Egypt         True

# %%
cars.iloc[[1]]
# Out:
#      cars_per_cpc    country drives_right
# AUS           731  Australia        False

# %%
cars.loc[["AUS"]]
# Out:
#      cars_per_cpc    country drives_right
# AUS           731  Australia        False

# %%
cars.iloc[5,2]
# Out:
# True

# %%
cars.loc[["RU","MOR"],["country",'drives_right']]
# Out:
#      country drives_right
# RU    Russia         True
# MOR  Morocco         True

# %%
cars.loc[:,["drives_right"]]
# Out:
#     drives_right
# US          True
# AUS        False
# JAP        False
# IN         False
# RU          True
# MOR         True
# EG          True

# %%
cars.loc[:,"drives_right"]
# Out:
# US      True
# AUS    False
# JAP    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool

# %%
cars.loc[:,["cars_per_cpc","drives_right"]]
# Out:
#      cars_per_cpc drives_right
# US            809         True
# AUS           731        False
# JAP           588        False
# IN             18        False
# RU            200         True
# MOR            70         True
# EG             45         True
